# %%
#Funciones nativas
type(x)
print(x)
#len detecta la longuitud que hay en x
len(x)
#Rango de valores 0 inicio , 3 final sin incluir, si pones una cosa entiende que es el final y el inicio por defecto coge 0
#range(x,x, +2) que avance de dos en dos
range(x, x)

#ESTADO DE VARIABLES
# 1. Indefinido
# variable no esta creada

# 2. Nulo
# null = None
# implica que esta ocupando espacio, no tiene tipo asignado, no tiene contenido

# 3. Cada variable tiene una forma de representarse en este estado
# la variable ocupa espacio, tiene tipo asignado y no tiene contenido
# todas equivalen a falso
patata =[]
numero = 0
decimal = 0.0
texto = ''
estado = False

# 4.
# la variable ocupa espacio, tiene tipo asignado y tiene contenido
# todas equivalen a verdadero
lista = [1,2,3]
numero = 4
decimal = 1.3
verdadero = True

#BUCLES

#FORMA FACIL: for
#sintaxis. lista = objeto que quieres recorrer. nunca trabajas con el objeto de dentro de la lista en el bucle
#trabajar con la variable iteradora, no puede comenzar con numero, ni espacios, ni puede existir antes, nombre en singular
# tiempo computacional = tantos elementos como haya en la lista
#cambiar nombre preferiblemente por lo que haya en la lista
for variable_iteradora in lista:

#FORMA DIFICIL no entra en examen : while
#lo que pongas dentro se repite siempre que la condicion = true
#1. crear variable iteradora y darle un valor
#2. avanzar variable iteradora
#3. condicion, cuando queremos que pare
posicion = 0
while posicion < len(colores):
  variable_iteradora = colores[posicion]
  posicion= posicion + 1
  print(variable_iteradora)
break # para salir del bucle para busquedas
continue #para continuar con el bucle
#despues de _ nombre del archivo
variable = pd.read_csv("ruta")
#como seleccionar una columna entre corchetes solo puedes pasar una cosa
variable["nombre_columna"]
variable[lista]
lista =["columna1","columna2"]
#los corchetes de dentro son una lista
#con numero es para seleccionar filas
variable[['columna1', 'columna2']]
#importar librerias
import pandas as pd
import numpy as np

#tupla- no es mutable, no se puede añadir ni quitar nada
#sucesion de valores separados por comas entre parentesis
ciudades =("Barcelona","Madrid","Valencia","Málaga","Bilbao")
#conjuntos- entre llaves, quita los repetidos tiene otras funciones distintas
#append - add, marca la posición automáticamente

#diccionarios- son sucesiones de valores separados por comas y entre llaves, pueden estar indexados por numeros o por texto
lista=["Hola", "soy", "Ana"]
lista[1]
diccionario = {0:"Hola",1:"soy", 2:"Ana", "persona":"Juan"}
diccionario["persona"]
#solo reconoce los indexadores que tu le has indicado

# %% [markdown]
# **IA **
# computers doing things that we would normally think of as intelligent in humans
# engloba programas de machine learning y deep learning
# en la práctica:
# modelos predictivos- diferenciar entre sencillo y dificil
# casos de uso: ventas, atencion al cliente, salud- diagnostico preventivo, mantenimiento predictivo,
# servicios cognitivos - separados por decision, vision, speech and language. Se pueden personalizar.
# casos de usos: analisis de grabaciones/ audio y analisis de imagenes
# show me the present- analisis de imagen avanzado, aprendizaje por refuerzo- comportamientos y generacion de contenido
#
#
# **MACHINE LEARNING **
# capacidad de aprender
# necesitan un periodo de aprendizaje
# modelos predictivos
# tareas simples
# funciones a las que les mandamos datos para que sepa dar respuestas
# el algoritmo no esta 100% seguro, puede haber fallos
# porcentaje de confianza, segun la fase de aprendizaje es mayor o menor
# de manera continua se realiza el re-entrenamiento
# tienes que empezar de 0 para actualizarse con datos nuevos
# aprendizaje reforzado, para aprender en robots, tu le estableces las reglas de funcionamiento, aprende probando y una persona le dice si lo esta haciendo bien o no
#
# **DEEP LEARNING**
# algoritmos mas potentes
# redes neuronales
# trabajan con numeros y datos ricamente hablando(texto, etc)
# problemas mas complejos
# ponen los algoritmos por capas y hay unos datos de entrada que van entrando por un camino u otro y te da un resultado
# descomponen la foto en formas, básicas, medias y avanzadas
# aprendizaje reforzado, para aprender en robots, tu le estableces las reglas de funcionamiento, aprende probando y una persona le dice si lo esta haciendo bien o no

# %%
#pip- instalar en el ordenador
#quiet- para que no printee codigo
#import- indicar que queremos usarlo
yf #tiene una libreria en python

#Subir archivos a google colab
#1.
#2. Carpeta, montar drive, ejecutar codigo y darle a aceptar, se actualiza y aparece una carpeta 'drive'
#clic derecho - copiar ruta

#Para hacer la media
.mean()
#Insertar un elemento a una lista en un sitio específico
insert()
#Borrar nulos
dropna()

# %%
#SQL Y PYTHON
#SQLAlchemy
df.to_sql #para meter datos y crear tablas
pd.read_sql(variable que quieras leer, engine) #leer los datos
#STRING para escribir con sql """
